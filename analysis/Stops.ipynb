# %%
from botigo import lacub

client = lacub.LacubAPI()
stops = client.get_stops()

# %%
import pandas as pd
stops = pd.DataFrame(stops)
stops.head()
# Out:
#                  cdate   gid   latitude      libelle  longitude  \
# 0  2017-03-26T04:15:10  1484  45.017352  Fort Lajard  -0.577169
# 1  2017-03-26T04:15:10  1483  45.017345  Fort Lajard  -0.577130
# 2  2017-03-26T04:15:13  2258  45.021846     Le Mayne  -0.575880
# 3  2017-03-26T04:15:17  3311  45.025554   Port Lopès  -0.576041
# 4  2017-03-26T04:15:13  2257  45.021725     Le Mayne  -0.575733
#
#                  mdate type
# 0  2017-03-26T04:15:10  BUS
# 1  2017-03-26T04:15:10  BUS
# 2  2017-03-26T04:15:13  BUS
# 3  2017-03-26T04:15:17  BUS
# 4  2017-03-26T04:15:13  BUS

# %%
stops.type.unique()
# Out:
# array(['BUS', 'TRAM'], dtype=object)

# %%
tram_stops = stops[stops.type == 'TRAM']
tram_stops.head()
# Out:
#                    cdate   gid   latitude         libelle  longitude  \
# 382  2017-03-26T04:15:22  4313  44.893268  Parc Des Expos  -0.565822
# 383  2017-03-26T04:15:22  4314  44.893296  Parc Des Expos  -0.565972
# 384  2017-03-26T04:15:22  3020  44.893345  Parc Des Expos  -0.565790
# 488  2017-03-26T04:15:22  2064  44.850712      La Maregue  -0.508920
# 489  2017-03-26T04:15:22  2065  44.850784      La Maregue  -0.508863
#
#                    mdate  type
# 382  2017-03-26T04:15:22  TRAM
# 383  2017-03-26T04:15:22  TRAM
# 384  2017-03-26T04:15:22  TRAM
# 488  2017-03-26T04:15:22  TRAM
# 489  2017-03-26T04:15:22  TRAM

# %%
import folium

BORDEAUX_LOC = {
    'lat': 44.8404400,
    'lon': -0.5805000
}

map_bdx = folium.Map(location=[BORDEAUX_LOC['lat'], BORDEAUX_LOC['lon']], zoom_start=12)
map_bdx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for row in tram_stops.itertuples():
    folium.Marker(location=[row.latitude, row.longitude], popup=row.libelle).add_to(map_bdx)

# %%
map_bdx
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
